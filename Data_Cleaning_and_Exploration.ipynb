# %% [markdown]
# <a href="https://colab.research.google.com/github/Shawn1997-collab/Data-Analysis-Portfolio/blob/main/Data_Cleaning_and_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Cleaning and Exploration
#
# ---

# %% [markdown]
# <br>
# This dataset contains information of cars purchased at the Auction.<br>
# <br>
# SOME VARIABLE DESCRIPTIONS:<br>
# Auction: Auction provider at which the  vehicle was purchased<br>
# Color: Vehicle Color<br>
# IsBadBuy: Identifies if the kicked vehicle was an avoidable purchase<br>
# MMRCurrentAuctionAveragePrice: Acquisition price for this vehicle in average condition as of current day<br>
# Size: The size category of the vehicle (Compact, SUV, etc.)<br>
# TopThreeAmericanName:Identifies if the manufacturer is one of the top three American manufacturers<br>
# VehBCost: Acquisition cost paid for the vehicle at time of purchase<br>
# VehicleAge: The Years elapsed since the manufacturer's year<br>
# VehOdo: The vehicles odometer reading<br>
# WarrantyCost: Warranty price (term=36month  and millage=36K)<br>
# WheelType: The vehicle wheel type description (Alloy, Covers)<br>

# %% [markdown]
# ###1. Upload and clean data

# %%
# Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import packages
import pandas as pd
import seaborn as sns

# %%
carAuction = pd.read_csv("/content/drive/MyDrive/data/car_kick.csv")
carAuction
# Out:
#         PurchDate  VehYear  VehicleAge  VehOdo  \
# 0      1289952000     2006           4   51954
# 1      1242691200     2005           4   89127
# 2      1248220800     2006           3   71271
# 3      1285718400     2008           2   83338
# 4      1237334400     2007           2   58698
# ...           ...      ...         ...     ...
# 67206  1285804800     2008           2   56072
# 67207  1274918400     2004           6   94232
# 67208  1280448000     2004           6   79534
# 67209  1285200000     2003           7   79394
# 67210  1288742400     2004           6   94491
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 0                                   6197                             7062
# 1                                   3688                             4783
# 2                                   6897                             8449
# 3                                   7878                             8925
# 4                                   8800                            10091
# ...                                  ...                              ...
# 67206                               6255                             6972
# 67207                               8359                             9645
# 67208                               2805                             3826
# 67209                               4042                             5296
# 67210                               5194                             6424
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# 0                                  9605                          10426
# 1                                  4483                           5666
# 2                                  7949                           9625
# 3                                 11723                          13026
# 4                                 10004                          11398
# ...                                 ...                            ...
# 67206                              9852                          10567
# 67207                             12042                          13302
# 67208                              6132                           6871
# 67209                              7335                           8983
# 67210                              8532                           9941
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  ...  \
# 0                               5341                         6351  ...
# 1                               3688                         4783  ...
# 2                               6868                         8549  ...
# 3                               7801                         8704  ...
# 4                               7355                         8543  ...
# ...                              ...                          ...  ...
# 67206                           6326                         7126  ...
# 67207                           7505                         8188  ...
# 67208                           3106                         4479  ...
# 67209                           3534                         4732  ...
# 67210                           4417                         5807  ...
#
#        WheelTypeID  WheelType       Nationality          Size  \
# 0                2     Covers          AMERICAN        MEDIUM
# 1                2     Covers          AMERICAN        MEDIUM
# 2                1      Alloy          AMERICAN         LARGE
# 3                2     Covers          AMERICAN         LARGE
# 4                1      Alloy          AMERICAN         LARGE
# ...            ...        ...               ...           ...
# 67206            2     Covers          AMERICAN        MEDIUM
# 67207            1      Alloy  'TOP LINE ASIAN'  'MEDIUM SUV'
# 67208            1      Alloy          AMERICAN        MEDIUM
# 67209            2     Covers          AMERICAN  'MEDIUM SUV'
# 67210            1      Alloy     'OTHER ASIAN'        MEDIUM
#
#       TopThreeAmericanName  BYRNO VNZIP1 VNST IsOnlineSale IsBadBuy
# 0                 CHRYSLER  99750  32124   FL            0        0
# 1                     FORD  20833  78754   TX            0        0
# 2                       GM  22916  80011   CO            0        0
# 3                       GM  23657  94544   CA            0        0
# 4                       GM  20833  77086   TX            0        0
# ...                    ...    ...    ...  ...          ...      ...
# 67206             CHRYSLER  22808  77061   TX            0        1
# 67207                OTHER  17675  28273   NC            0        1
# 67208                   GM  18880  37771   TN            0        1
# 67209                   GM  23657  92337   CA            0        1
# 67210                OTHER    835  87105   NM            0        1
#
# [67211 rows x 31 columns]

# %%
# Examine the number of rows and cols
carAuction.shape
# Out:
# (67211, 31)

# %%
# Show the head rows of a data frame
carAuction.head()
# Out:
#     PurchDate  VehYear  VehicleAge  VehOdo  MMRAcquisitionAuctionAveragePrice  \
# 0  1289952000     2006           4   51954                               6197
# 1  1242691200     2005           4   89127                               3688
# 2  1248220800     2006           3   71271                               6897
# 3  1285718400     2008           2   83338                               7878
# 4  1237334400     2007           2   58698                               8800
#
#    MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 0                             7062                              9605
# 1                             4783                              4483
# 2                             8449                              7949
# 3                             8925                             11723
# 4                            10091                             10004
#
#    MMRAcquisitonRetailCleanPrice  MMRCurrentAuctionAveragePrice  \
# 0                          10426                           5341
# 1                           5666                           3688
# 2                           9625                           6868
# 3                          13026                           7801
# 4                          11398                           7355
#
#    MMRCurrentAuctionCleanPrice  ...  WheelTypeID  WheelType  Nationality  \
# 0                         6351  ...            2     Covers     AMERICAN
# 1                         4783  ...            2     Covers     AMERICAN
# 2                         8549  ...            1      Alloy     AMERICAN
# 3                         8704  ...            2     Covers     AMERICAN
# 4                         8543  ...            1      Alloy     AMERICAN
#
#      Size TopThreeAmericanName  BYRNO VNZIP1 VNST IsOnlineSale IsBadBuy
# 0  MEDIUM             CHRYSLER  99750  32124   FL            0        0
# 1  MEDIUM                 FORD  20833  78754   TX            0        0
# 2   LARGE                   GM  22916  80011   CO            0        0
# 3   LARGE                   GM  23657  94544   CA            0        0
# 4   LARGE                   GM  20833  77086   TX            0        0
#
# [5 rows x 31 columns]

# %%
# Examine missing values again
carAuction.isnull().sum()
# Out:
# PurchDate                            0
# VehYear                              0
# VehicleAge                           0
# VehOdo                               0
# MMRAcquisitionAuctionAveragePrice    0
# MMRAcquisitionAuctionCleanPrice      0
# MMRAcquisitionRetailAveragePrice     0
# MMRAcquisitonRetailCleanPrice        0
# MMRCurrentAuctionAveragePrice        0
# MMRCurrentAuctionCleanPrice          0
# MMRCurrentRetailAveragePrice         0
# MMRCurrentRetailCleanPrice           0
# VehBCost                             0
# WarrantyCost                         0
# Auction                              0
# Make                                 0
# Model                                0
# Trim                                 0
# SubModel                             0
# Color                                0
# Transmission                         0
# WheelTypeID                          0
# WheelType                            0
# Nationality                          0
# Size                                 0
# TopThreeAmericanName                 0
# BYRNO                                0
# VNZIP1                               0
# VNST                                 0
# IsOnlineSale                         0
# IsBadBuy                             0
# dtype: int64

# %%
# Examine variable type (0.5 pts)
carAuction.dtypes
# Out:
# PurchDate                             int64
# VehYear                               int64
# VehicleAge                            int64
# VehOdo                                int64
# MMRAcquisitionAuctionAveragePrice     int64
# MMRAcquisitionAuctionCleanPrice       int64
# MMRAcquisitionRetailAveragePrice      int64
# MMRAcquisitonRetailCleanPrice         int64
# MMRCurrentAuctionAveragePrice         int64
# MMRCurrentAuctionCleanPrice           int64
# MMRCurrentRetailAveragePrice          int64
# MMRCurrentRetailCleanPrice            int64
# VehBCost                              int64
# WarrantyCost                          int64
# Auction                              object
# Make                                 object
# Model                                object
# Trim                                 object
# SubModel                             object
# Color                                object
# Transmission                         object
# WheelTypeID                           int64
# WheelType                            object
# Nationality                          object
# Size                                 object
# TopThreeAmericanName                 object
# BYRNO                                 int64
# VNZIP1                                int64
# VNST                                 object
# IsOnlineSale                          int64
# IsBadBuy                              int64
# dtype: object

# %%
# Change the following categorical variables to "category" (1 pt)
carAuction['Auction'] = carAuction['Auction'].astype('category')
carAuction['Color'] = carAuction['Color'].astype('category')
carAuction['IsBadBuy'] = carAuction['IsBadBuy'].astype('category')
carAuction['Size'] = carAuction['Size'].astype('category')
carAuction['TopThreeAmericanName'] = carAuction['Size'].astype('category')
carAuction['WheelType'] = carAuction['Size'].astype('category')

# %%
# Display all numeric variables (0.5 pts)
carAuction.select_dtypes(include=['number'])
# Out:
#         PurchDate  VehYear  VehicleAge  VehOdo  \
# 0      1289952000     2006           4   51954
# 1      1242691200     2005           4   89127
# 2      1248220800     2006           3   71271
# 3      1285718400     2008           2   83338
# 4      1237334400     2007           2   58698
# ...           ...      ...         ...     ...
# 67206  1285804800     2008           2   56072
# 67207  1274918400     2004           6   94232
# 67208  1280448000     2004           6   79534
# 67209  1285200000     2003           7   79394
# 67210  1288742400     2004           6   94491
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 0                                   6197                             7062
# 1                                   3688                             4783
# 2                                   6897                             8449
# 3                                   7878                             8925
# 4                                   8800                            10091
# ...                                  ...                              ...
# 67206                               6255                             6972
# 67207                               8359                             9645
# 67208                               2805                             3826
# 67209                               4042                             5296
# 67210                               5194                             6424
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# 0                                  9605                          10426
# 1                                  4483                           5666
# 2                                  7949                           9625
# 3                                 11723                          13026
# 4                                 10004                          11398
# ...                                 ...                            ...
# 67206                              9852                          10567
# 67207                             12042                          13302
# 67208                              6132                           6871
# 67209                              7335                           8983
# 67210                              8532                           9941
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  \
# 0                               5341                         6351
# 1                               3688                         4783
# 2                               6868                         8549
# 3                               7801                         8704
# 4                               7355                         8543
# ...                              ...                          ...
# 67206                           6326                         7126
# 67207                           7505                         8188
# 67208                           3106                         4479
# 67209                           3534                         4732
# 67210                           4417                         5807
#
#        MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice  VehBCost  \
# 0                              8513                        9822      6500
# 1                              4483                        5666      3680
# 2                              7917                        9733      7170
# 3                             11995                       12901      7670
# 4                              8443                        9726      7165
# ...                             ...                         ...       ...
# 67206                          9951                       10806      6680
# 67207                         10993                       11655      8265
# 67208                          5981                        7256      4950
# 67209                          7165                        8538      5220
# 67210                          7814                        9366      5890
#
#        WarrantyCost  WheelTypeID  BYRNO  VNZIP1  IsOnlineSale
# 0              1086            2  99750   32124             0
# 1               983            2  20833   78754             0
# 2              1974            1  22916   80011             0
# 3              2152            2  23657   94544             0
# 4              1500            1  20833   77086             0
# ...             ...          ...    ...     ...           ...
# 67206          1086            2  22808   77061             0
# 67207           909            1  17675   28273             0
# 67208          1506            1  18880   37771             0
# 67209          3967            2  23657   92337             0
# 67210          1774            1    835   87105             0
#
# [67211 rows x 18 columns]

# %%
# Display all categorical variables (0.5 pts)
carAuction.select_dtypes(include=['category'])
# Out:
#        Auction   Color     WheelType          Size TopThreeAmericanName  \
# 0      MANHEIM  SILVER        MEDIUM        MEDIUM               MEDIUM
# 1        ADESA  SILVER        MEDIUM        MEDIUM               MEDIUM
# 2      MANHEIM     RED         LARGE         LARGE                LARGE
# 3      MANHEIM   BLACK         LARGE         LARGE                LARGE
# 4        ADESA   WHITE         LARGE         LARGE                LARGE
# ...        ...     ...           ...           ...                  ...
# 67206  MANHEIM     RED        MEDIUM        MEDIUM               MEDIUM
# 67207    ADESA   BLACK  'MEDIUM SUV'  'MEDIUM SUV'         'MEDIUM SUV'
# 67208    ADESA    GOLD        MEDIUM        MEDIUM               MEDIUM
# 67209  MANHEIM   WHITE  'MEDIUM SUV'  'MEDIUM SUV'         'MEDIUM SUV'
# 67210  MANHEIM     RED        MEDIUM        MEDIUM               MEDIUM
#
#       IsBadBuy
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 67206        1
# 67207        1
# 67208        1
# 67209        1
# 67210        1
#
# [67211 rows x 6 columns]

# %% [markdown]
# ###2. Understanding a single variable: numeric variables

# %%
# Show the statistics of VehOdo (0.5 pts)
carAuction['VehOdo'].describe()
# Out:
# count     67211.000000
# mean      71734.558971
# std       14387.245482
# min        5368.000000
# 25%       62163.000000
# 50%       73530.000000
# 75%       82530.000000
# max      115717.000000
# Name: VehOdo, dtype: float64

# %%
# Obtain the variance, standard deviation, and range of WarrantyCost (0.5 pts)
print("variance: ", carAuction['WarrantyCost'].var(), "standard deviation: ", carAuction['WarrantyCost'].std(), "range: ", carAuction['WarrantyCost'].min(), carAuction['WarrantyCost'].max())
# Out:
# variance:  335331.08427681215 standard deviation:  579.0777877598243 range:  462 7498

# %%
# Display the IQR of WarrantyCost (0.5 pts)
IQR = carAuction['WarrantyCost'].quantile(0.75) - carAuction['WarrantyCost'].quantile(0.25)
print("IQR:", IQR)
# Out:
# IQR: 770.0

# %%
# Boxplot of a numeric variable: VehBCost (0.5 pts)
snsplot = sns.boxplot(x='VehBCost', data = carAuction)
snsplot.set_title("Boxplot of VehBCost in the carAuction data set")
# Out:
# Text(0.5, 1.0, 'Boxplot of VehBCost in the carAuction data set')

# %%
# Boxplot of a numeric variable: VehicleAge (0.5 pts)
snsplot = sns.boxplot(x='VehicleAge', data = carAuction)
snsplot.set_title("Boxplot of VehicleAge in the carAuction data set")
# Out:
# Text(0.5, 1.0, 'Boxplot of VehicleAge in the carAuction data set')

# %%
# Histogram of a numeric variable: VehOdo (0.5 pts)
snsplot = sns.histplot(x='VehOdo', data = carAuction)
snsplot.set_title("Histogram of VehOdo in the carAuction data set")
# Out:
# Text(0.5, 1.0, 'Histogram of VehOdo in the carAuction data set')

# %% [markdown]
# ###3. Understanding a single variable: categorical variables

# %%
# Display the number of cars in different WheelType (0.5 pts)
carAuction['WheelType'].value_counts()
#carAuction['WheelType']
# Out:
# WheelType
# MEDIUM           28375
# LARGE             8444
# 'MEDIUM SUV'      7149
# COMPACT           6546
# VAN               5422
# 'LARGE TRUCK'     3044
# 'SMALL SUV'       2162
# SPECIALTY         1747
# CROSSOVER         1433
# 'LARGE SUV'       1342
# 'SMALL TRUCK'      822
# SPORTS             725
# Name: count, dtype: int64

# %%
# Display the proportion of cars in different WheelType (0.5 pts)
carAuction['WheelType'].value_counts(normalize=True)
# Out:
# WheelType
# MEDIUM           0.422178
# LARGE            0.125634
# 'MEDIUM SUV'     0.106367
# COMPACT          0.097395
# VAN              0.080671
# 'LARGE TRUCK'    0.045290
# 'SMALL SUV'      0.032167
# SPECIALTY        0.025993
# CROSSOVER        0.021321
# 'LARGE SUV'      0.019967
# 'SMALL TRUCK'    0.012230
# SPORTS           0.010787
# Name: proportion, dtype: float64

# %%
# Plot a categorical variable: WheelType (0.5 pts)
snsplot = sns.countplot(x='WheelType', data=carAuction)
snsplot.set_title("countplot of WheelType in the carAuction data set")
# Out:
# Text(0.5, 1.0, 'countplot of WheelType in the carAuction data set')

# %% [markdown]
# ### 4. Understand relationships of multiple variables

# %%
# scatter plot two numeric variables: VehBCost and MMRCurrentAuctionAveragePrice (0.5 pts)
snsplot = sns.scatterplot(x='VehBCost', y= 'MMRCurrentAuctionAveragePrice', data=carAuction)
snsplot.set_title("Scatterplot of VehBCost and MMRCurrentAuctionAveragePrice")
# Out:
# Text(0.5, 1.0, 'Scatterplot of VehBCost and MMRCurrentAuctionAveragePrice')

# %%
# Generate correlation coefficients of two numeric variables in a 2x2 matrix: VehBCost and MMRCurrentAuctionAveragePrice (0.5 pts)
carAuction[['VehBCost','MMRCurrentAuctionAveragePrice']].corr()
# Out:
#                                VehBCost  MMRCurrentAuctionAveragePrice
# VehBCost                       1.000000                       0.775695
# MMRCurrentAuctionAveragePrice  0.775695                       1.000000

# %%
# Generate the correlation matrix of all numeric variables (0.5 pts)
carAuction.select_dtypes(include=['number']).corr()
# Out:
#                                    PurchDate   VehYear  VehicleAge    VehOdo  \
# PurchDate                           1.000000  0.215292    0.037169  0.135764
# VehYear                             0.215292  1.000000   -0.957778 -0.269816
# VehicleAge                          0.037169 -0.957778    1.000000  0.307065
# VehOdo                              0.135764 -0.269816    0.307065  1.000000
# MMRAcquisitionAuctionAveragePrice   0.087046  0.593798   -0.577551 -0.013847
# MMRAcquisitionAuctionCleanPrice     0.085459  0.545082   -0.530308  0.027539
# MMRAcquisitionRetailAveragePrice    0.418429  0.591529   -0.470060  0.036081
# MMRAcquisitonRetailCleanPrice       0.395157  0.549593   -0.435900  0.068045
# MMRCurrentAuctionAveragePrice       0.070239  0.604523   -0.588476 -0.028840
# MMRCurrentAuctionCleanPrice         0.073578  0.561668   -0.544866  0.012019
# MMRCurrentRetailAveragePrice        0.370513  0.609667   -0.514644  0.017334
# MMRCurrentRetailCleanPrice          0.352903  0.569607   -0.479823  0.050215
# VehBCost                            0.149411  0.366190   -0.327180 -0.063236
# WarrantyCost                       -0.034676 -0.245601    0.237107  0.406373
# WheelTypeID                         0.045311  0.250752   -0.242197 -0.205637
# BYRNO                               0.084833  0.279578   -0.268127 -0.295920
# VNZIP1                             -0.030193  0.068995   -0.076431 -0.057613
# IsOnlineSale                        0.109462  0.059679   -0.026979  0.028611
#
#                                    MMRAcquisitionAuctionAveragePrice  \
# PurchDate                                                   0.087046
# VehYear                                                     0.593798
# VehicleAge                                                 -0.577551
# VehOdo                                                     -0.013847
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.990203
# MMRAcquisitionRetailAveragePrice                            0.910035
# MMRAcquisitonRetailCleanPrice                               0.910251
# MMRCurrentAuctionAveragePrice                               0.936045
# MMRCurrentAuctionCleanPrice                                 0.930733
# MMRCurrentRetailAveragePrice                                0.870604
# MMRCurrentRetailCleanPrice                                  0.870059
# VehBCost                                                    0.787583
# WarrantyCost                                               -0.046797
# WheelTypeID                                                -0.088441
# BYRNO                                                       0.106235
# VNZIP1                                                      0.040638
# IsOnlineSale                                                0.039856
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# PurchDate                                                 0.085459
# VehYear                                                   0.545082
# VehicleAge                                               -0.530308
# VehOdo                                                    0.027539
# MMRAcquisitionAuctionAveragePrice                         0.990203
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.902069
# MMRAcquisitonRetailCleanPrice                             0.918252
# MMRCurrentAuctionAveragePrice                             0.921498
# MMRCurrentAuctionCleanPrice                               0.930204
# MMRCurrentRetailAveragePrice                              0.859252
# MMRCurrentRetailCleanPrice                                0.870091
# VehBCost                                                  0.778811
# WarrantyCost                                             -0.017216
# WheelTypeID                                              -0.122610
# BYRNO                                                     0.060725
# VNZIP1                                                    0.035764
# IsOnlineSale                                              0.039418
#
#                                    MMRAcquisitionRetailAveragePrice  \
# PurchDate                                                  0.418429
# VehYear                                                    0.591529
# VehicleAge                                                -0.470060
# VehOdo                                                     0.036081
# MMRAcquisitionAuctionAveragePrice                          0.910035
# MMRAcquisitionAuctionCleanPrice                            0.902069
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.990173
# MMRCurrentAuctionAveragePrice                              0.849579
# MMRCurrentAuctionCleanPrice                                0.847423
# MMRCurrentRetailAveragePrice                               0.911233
# MMRCurrentRetailCleanPrice                                 0.904172
# VehBCost                                                   0.744788
# WarrantyCost                                              -0.048821
# WheelTypeID                                               -0.067167
# BYRNO                                                      0.104626
# VNZIP1                                                     0.030721
# IsOnlineSale                                               0.081930
#
#                                    MMRAcquisitonRetailCleanPrice  \
# PurchDate                                               0.395157
# VehYear                                                 0.549593
# VehicleAge                                             -0.435900
# VehOdo                                                  0.068045
# MMRAcquisitionAuctionAveragePrice                       0.910251
# MMRAcquisitionAuctionCleanPrice                         0.918252
# MMRAcquisitionRetailAveragePrice                        0.990173
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.844974
# MMRCurrentAuctionCleanPrice                             0.853976
# MMRCurrentRetailAveragePrice                            0.901305
# MMRCurrentRetailCleanPrice                              0.904965
# VehBCost                                                0.743548
# WarrantyCost                                           -0.022398
# WheelTypeID                                            -0.096681
# BYRNO                                                   0.066875
# VNZIP1                                                  0.026629
# IsOnlineSale                                            0.078570
#
#                                    MMRCurrentAuctionAveragePrice  \
# PurchDate                                               0.070239
# VehYear                                                 0.604523
# VehicleAge                                             -0.588476
# VehOdo                                                 -0.028840
# MMRAcquisitionAuctionAveragePrice                       0.936045
# MMRAcquisitionAuctionCleanPrice                         0.921498
# MMRAcquisitionRetailAveragePrice                        0.849579
# MMRAcquisitonRetailCleanPrice                           0.844974
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990136
# MMRCurrentRetailAveragePrice                            0.914828
# MMRCurrentRetailCleanPrice                              0.912118
# VehBCost                                                0.775695
# WarrantyCost                                           -0.054842
# WheelTypeID                                            -0.080319
# BYRNO                                                   0.111814
# VNZIP1                                                  0.044082
# IsOnlineSale                                            0.041556
#
#                                    MMRCurrentAuctionCleanPrice  \
# PurchDate                                             0.073578
# VehYear                                               0.561668
# VehicleAge                                           -0.544866
# VehOdo                                                0.012019
# MMRAcquisitionAuctionAveragePrice                     0.930733
# MMRAcquisitionAuctionCleanPrice                       0.930204
# MMRAcquisitionRetailAveragePrice                      0.847423
# MMRAcquisitonRetailCleanPrice                         0.853976
# MMRCurrentAuctionAveragePrice                         0.990136
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.908335
# MMRCurrentRetailCleanPrice                            0.921654
# VehBCost                                              0.771718
# WarrantyCost                                         -0.026039
# WheelTypeID                                          -0.113057
# BYRNO                                                 0.068482
# VNZIP1                                                0.038696
# IsOnlineSale                                          0.041753
#
#                                    MMRCurrentRetailAveragePrice  \
# PurchDate                                              0.370513
# VehYear                                                0.609667
# VehicleAge                                            -0.514644
# VehOdo                                                 0.017334
# MMRAcquisitionAuctionAveragePrice                      0.870604
# MMRAcquisitionAuctionCleanPrice                        0.859252
# MMRAcquisitionRetailAveragePrice                       0.911233
# MMRAcquisitonRetailCleanPrice                          0.901305
# MMRCurrentAuctionAveragePrice                          0.914828
# MMRCurrentAuctionCleanPrice                            0.908335
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989710
# VehBCost                                               0.756046
# WarrantyCost                                          -0.054601
# WheelTypeID                                           -0.067778
# BYRNO                                                  0.110371
# VNZIP1                                                 0.036844
# IsOnlineSale                                           0.080710
#
#                                    MMRCurrentRetailCleanPrice  VehBCost  \
# PurchDate                                            0.352903  0.149411
# VehYear                                              0.569607  0.366190
# VehicleAge                                          -0.479823 -0.327180
# VehOdo                                               0.050215 -0.063236
# MMRAcquisitionAuctionAveragePrice                    0.870059  0.787583
# MMRAcquisitionAuctionCleanPrice                      0.870091  0.778811
# MMRAcquisitionRetailAveragePrice                     0.904172  0.744788
# MMRAcquisitonRetailCleanPrice                        0.904965  0.743548
# MMRCurrentAuctionAveragePrice                        0.912118  0.775695
# MMRCurrentAuctionCleanPrice                          0.921654  0.771718
# MMRCurrentRetailAveragePrice                         0.989710  0.756046
# MMRCurrentRetailCleanPrice                           1.000000  0.755716
# VehBCost                                             0.755716  1.000000
# WarrantyCost                                        -0.027835 -0.036948
# WheelTypeID                                         -0.096149 -0.153201
# BYRNO                                                0.073660  0.043945
# VNZIP1                                               0.032281  0.010096
# IsOnlineSale                                         0.077323  0.034595
#
#                                    WarrantyCost  WheelTypeID     BYRNO  \
# PurchDate                             -0.034676     0.045311  0.084833
# VehYear                               -0.245601     0.250752  0.279578
# VehicleAge                             0.237107    -0.242197 -0.268127
# VehOdo                                 0.406373    -0.205637 -0.295920
# MMRAcquisitionAuctionAveragePrice     -0.046797    -0.088441  0.106235
# MMRAcquisitionAuctionCleanPrice       -0.017216    -0.122610  0.060725
# MMRAcquisitionRetailAveragePrice      -0.048821    -0.067167  0.104626
# MMRAcquisitonRetailCleanPrice         -0.022398    -0.096681  0.066875
# MMRCurrentAuctionAveragePrice         -0.054842    -0.080319  0.111814
# MMRCurrentAuctionCleanPrice           -0.026039    -0.113057  0.068482
# MMRCurrentRetailAveragePrice          -0.054601    -0.067778  0.110371
# MMRCurrentRetailCleanPrice            -0.027835    -0.096149  0.073660
# VehBCost                              -0.036948    -0.153201  0.043945
# WarrantyCost                           1.000000    -0.115015 -0.084051
# WheelTypeID                           -0.115015     1.000000  0.188521
# BYRNO                                 -0.084051     0.188521  1.000000
# VNZIP1                                -0.041593     0.010111  0.034151
# IsOnlineSale                           0.005649    -0.006185 -0.141468
#
#                                      VNZIP1  IsOnlineSale
# PurchDate                         -0.030193      0.109462
# VehYear                            0.068995      0.059679
# VehicleAge                        -0.076431     -0.026979
# VehOdo                            -0.057613      0.028611
# MMRAcquisitionAuctionAveragePrice  0.040638      0.039856
# MMRAcquisitionAuctionCleanPrice    0.035764      0.039418
# MMRAcquisitionRetailAveragePrice   0.030721      0.081930
# MMRAcquisitonRetailCleanPrice      0.026629      0.078570
# MMRCurrentAuctionAveragePrice      0.044082      0.041556
# MMRCurrentAuctionCleanPrice        0.038696      0.041753
# MMRCurrentRetailAveragePrice       0.036844      0.080710
# MMRCurrentRetailCleanPrice         0.032281      0.077323
# VehBCost                           0.010096      0.034595
# WarrantyCost                      -0.041593      0.005649
# WheelTypeID                        0.010111     -0.006185
# BYRNO                              0.034151     -0.141468
# VNZIP1                             1.000000      0.024230
# IsOnlineSale                       0.024230      1.000000

# %%
# Examine relationships between numeric and categorical variables: boxplot VehBCost based on IsBadBuy (0.5 pts)
snsplot = sns.boxplot(x='VehBCost', y= 'IsBadBuy', data = carAuction)
snsplot.set_title("boxplot VehBCost based on IsBadBuy")
snsplot.set_xlim([1000, 10000])
# Out:
# (1000.0, 10000.0)

# %%
# !jupyter nbconvert --to html "/content/drive/MyDrive/Colab Notebooks/Data Cleaning and Exploration"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/Data Cleaning and Exploration.ipynb to html
# [NbConvertApp] Writing 298973 bytes to /content/drive/MyDrive/Colab Notebooks/Data Cleaning and Exploration.html
